# %%
#import dependencies 
from path import Path
import pandas as pd
import numpy as np
import re
from datetime import datetime as dt
from scipy import stats
import matplotlib.pyplot as plt

# %%
#import data
file_path = Path("./Resources/cbp_data.csv")
cbp_df = pd.read_csv(file_path, low_memory=False)
cbp_df
# Out:
#                     date_in             date_out             app_date  \
# 0       2017-01-20 00:10:00  2017-01-20 10:08:00                  NaN
# 1       2017-01-20 00:15:00  2017-01-24 17:30:00                  NaN
# 2       2017-01-20 00:22:00  2017-01-24 17:47:00                  NaN
# 3       2017-01-20 00:30:00  2017-01-21 06:35:00                  NaN
# 4       2017-01-20 00:30:00  2017-01-21 13:03:00                  NaN
# ...                     ...                  ...                  ...
# 583803  2020-06-18 14:00:55  2020-06-18 18:47:00  2020-06-18 16:03:56
# 583804  2020-06-18 16:07:39  2020-06-19 13:45:00  2020-06-18 16:24:08
# 583805  2020-06-19 09:34:16  2020-06-19 12:23:00  2020-06-19 09:45:22
# 583806  2020-06-19 14:40:00  2020-06-20 11:25:45  2020-06-19 12:43:29
# 583807  2020-06-19 10:46:25  2020-06-20 11:25:45  2020-06-19 13:06:33
#
#         hours_in_custody    age_group      gender  citizenship border  \
# 0               9.950000    6-8 years      Female  EL SALVADOR    SBO
# 1             113.233333    3-5 years      Female    GUATEMALA    SBO
# 2             113.416667    3-5 years      Female       BRAZIL    SBO
# 3              30.083333  12-14 years        Male  EL SALVADOR    SBO
# 4              36.533333    3-5 years        Male     HONDURAS    SBO
# ...                  ...          ...         ...          ...    ...
# 583803          4.770000  15-18 years    M - MALE       MEXICO    NaN
# 583804         21.620000  15-18 years    M - MALE       MEXICO    NaN
# 583805          2.810000  12-14 years  F - FEMALE       MEXICO    NaN
# 583806         20.760000  15-18 years  F - FEMALE       MEXICO    NaN
# 583807         24.660000  15-18 years    M - MALE       MEXICO    NaN
#
#             sector field_office source
# 0       (b)(7)(E )          NaN     BP
# 1       (b)(7)(E )          NaN     BP
# 2       (b)(7)(E )          NaN     BP
# 3       (b)(7)(E )          NaN     BP
# 4       (b)(7)(E )          NaN     BP
# ...            ...          ...    ...
# 583803         NaN       LAREDO    OFO
# 583804         NaN    SAN DIEGO    OFO
# 583805         NaN    SAN DIEGO    OFO
# 583806         NaN    SAN DIEGO    OFO
# 583807         NaN    SAN DIEGO    OFO
#
# [583808 rows x 11 columns]

# %%
#remove initial columns I don't need
cbp_df = cbp_df.drop(['app_date', 'sector', 'field_office', 'source'], axis=1).dropna()
cbp_df
#ends up dropping more because I kept the border column, which has more null values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-3351da39362d> in <module>
#       1 #remove initial columns I don't need
# ----> 2 cbp_df = cbp_df.drop(['app_date', 'sector', 'field_office', 'source'], axis=1).dropna()
#       3 cbp_df
#       4 #ends up dropping more because I kept the border column, which has more null values
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3988                 weight  1.0     0.8
#    3989         """
# -> 3990         return super().drop(
#    3991             labels=labels,
#    3992             axis=axis,
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['app_date' 'sector' 'field_office' 'source'] not found in axis"

# %%
#Clean gender column

#create dictionary 
genders = {'M - MALE': 'Male', 'F - FEMALE': 'Female', 'U - UNKNOWN': 'Unknown'}

#replace values in column
cbp_df['gender'] = cbp_df.gender.replace(genders)

# %%
#round hours in custody 
cbp_df['hours_in_custody'] = cbp_df.hours_in_custody.round(2)
cbp_df
# Out:
#                     date_in             date_out  hours_in_custody  \
# 0       2017-01-20 00:10:00  2017-01-20 10:08:00              9.95
# 1       2017-01-20 00:15:00  2017-01-24 17:30:00            113.23
# 2       2017-01-20 00:22:00  2017-01-24 17:47:00            113.42
# 3       2017-01-20 00:30:00  2017-01-21 06:35:00             30.08
# 4       2017-01-20 00:30:00  2017-01-21 13:03:00             36.53
# ...                     ...                  ...               ...
# 488813  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488814  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488815  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488816  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488817  2020-01-31 23:50:00  2020-02-05 02:39:00             98.80
#
#           age_group  gender  citizenship border
# 0         6-8 years  Female  EL SALVADOR    SBO
# 1         3-5 years  Female    GUATEMALA    SBO
# 2         3-5 years  Female       BRAZIL    SBO
# 3       12-14 years    Male  EL SALVADOR    SBO
# 4         3-5 years    Male     HONDURAS    SBO
# ...             ...     ...          ...    ...
# 488813    6-8 years  Female    VENEZUELA    SBO
# 488814  12-14 years  Female    VENEZUELA    SBO
# 488815   9-11 years    Male    VENEZUELA    SBO
# 488816  12-14 years  Female    VENEZUELA    SBO
# 488817  12-14 years  Female    VENEZUELA    SBO
#
# [487761 rows x 7 columns]

# %%
# Convert Hours in custody into days 
cbp_df['days_in_custody'] = cbp_df['hours_in_custody'] / 24
cbp_df
# Out:
#                     date_in             date_out  hours_in_custody  \
# 0       2017-01-20 00:10:00  2017-01-20 10:08:00              9.95
# 1       2017-01-20 00:15:00  2017-01-24 17:30:00            113.23
# 2       2017-01-20 00:22:00  2017-01-24 17:47:00            113.42
# 3       2017-01-20 00:30:00  2017-01-21 06:35:00             30.08
# 4       2017-01-20 00:30:00  2017-01-21 13:03:00             36.53
# ...                     ...                  ...               ...
# 488813  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488814  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488815  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488816  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488817  2020-01-31 23:50:00  2020-02-05 02:39:00             98.80
#
#           age_group  gender  citizenship border  days_in_custody
# 0         6-8 years  Female  EL SALVADOR    SBO         0.414583
# 1         3-5 years  Female    GUATEMALA    SBO         4.717917
# 2         3-5 years  Female       BRAZIL    SBO         4.725833
# 3       12-14 years    Male  EL SALVADOR    SBO         1.253333
# 4         3-5 years    Male     HONDURAS    SBO         1.522083
# ...             ...     ...          ...    ...              ...
# 488813    6-8 years  Female    VENEZUELA    SBO         1.385417
# 488814  12-14 years  Female    VENEZUELA    SBO         1.385417
# 488815   9-11 years    Male    VENEZUELA    SBO         1.385417
# 488816  12-14 years  Female    VENEZUELA    SBO         1.385417
# 488817  12-14 years  Female    VENEZUELA    SBO         4.116667
#
# [487761 rows x 8 columns]

# %%
#round hours in custody 
cbp_df['days_in_custody'] = cbp_df.days_in_custody.round(2)
cbp_df
# Out:
#                     date_in             date_out  hours_in_custody  \
# 0       2017-01-20 00:10:00  2017-01-20 10:08:00              9.95
# 1       2017-01-20 00:15:00  2017-01-24 17:30:00            113.23
# 2       2017-01-20 00:22:00  2017-01-24 17:47:00            113.42
# 3       2017-01-20 00:30:00  2017-01-21 06:35:00             30.08
# 4       2017-01-20 00:30:00  2017-01-21 13:03:00             36.53
# ...                     ...                  ...               ...
# 488813  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488814  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488815  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488816  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488817  2020-01-31 23:50:00  2020-02-05 02:39:00             98.80
#
#           age_group  gender  citizenship border  days_in_custody
# 0         6-8 years  Female  EL SALVADOR    SBO             0.41
# 1         3-5 years  Female    GUATEMALA    SBO             4.72
# 2         3-5 years  Female       BRAZIL    SBO             4.73
# 3       12-14 years    Male  EL SALVADOR    SBO             1.25
# 4         3-5 years    Male     HONDURAS    SBO             1.52
# ...             ...     ...          ...    ...              ...
# 488813    6-8 years  Female    VENEZUELA    SBO             1.39
# 488814  12-14 years  Female    VENEZUELA    SBO             1.39
# 488815   9-11 years    Male    VENEZUELA    SBO             1.39
# 488816  12-14 years  Female    VENEZUELA    SBO             1.39
# 488817  12-14 years  Female    VENEZUELA    SBO             4.12
#
# [487761 rows x 8 columns]

# %%
#drop negative values 
cbp_df.drop(cbp_df.loc[cbp_df['hours_in_custody']<0].index, inplace=True)
cbp_df
# Out:
#                     date_in             date_out  hours_in_custody  \
# 0       2017-01-20 00:10:00  2017-01-20 10:08:00              9.95
# 1       2017-01-20 00:15:00  2017-01-24 17:30:00            113.23
# 2       2017-01-20 00:22:00  2017-01-24 17:47:00            113.42
# 3       2017-01-20 00:30:00  2017-01-21 06:35:00             30.08
# 4       2017-01-20 00:30:00  2017-01-21 13:03:00             36.53
# ...                     ...                  ...               ...
# 488813  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488814  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488815  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488816  2020-01-31 23:50:00  2020-02-02 09:06:00             33.25
# 488817  2020-01-31 23:50:00  2020-02-05 02:39:00             98.80
#
#           age_group  gender  citizenship border  days_in_custody
# 0         6-8 years  Female  EL SALVADOR    SBO             0.41
# 1         3-5 years  Female    GUATEMALA    SBO             4.72
# 2         3-5 years  Female       BRAZIL    SBO             4.73
# 3       12-14 years    Male  EL SALVADOR    SBO             1.25
# 4         3-5 years    Male     HONDURAS    SBO             1.52
# ...             ...     ...          ...    ...              ...
# 488813    6-8 years  Female    VENEZUELA    SBO             1.39
# 488814  12-14 years  Female    VENEZUELA    SBO             1.39
# 488815   9-11 years    Male    VENEZUELA    SBO             1.39
# 488816  12-14 years  Female    VENEZUELA    SBO             1.39
# 488817  12-14 years  Female    VENEZUELA    SBO             4.12
#
# [487761 rows x 8 columns]

# %%
cbp_df.hours_in_custody.describe()
# Out:
# count    487761.000000
# mean         69.592357
# std          54.717287
# min           0.000000
# 25%          35.880000
# 50%          58.930000
# 75%          89.220000
# max         991.220000
# Name: hours_in_custody, dtype: float64

# %%
# Export to csv
cbp_df.to_csv(r'/Users/ebonybrown/Desktop/My_Projects/CBP_Detentions/Resources/cbp_tab.csv', index_label="unique_id")
